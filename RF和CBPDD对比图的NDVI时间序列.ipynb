# %%
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files
import matplotlib as mpl

# %%
# corn样本NDVI时间序列
corn_sample = [0.12158111, 0.13675252, 0.11746047, 0.15103779, 0.13258463, 0.17043263,
  0.27664024, 0.41980866, 0.66803447, 0.78002375, 0.84764778, 0.88367154,
  0.82070537, 0.68194665, 0.56755694, 0.27573394, 0.27925092, 0.25687497,
  0.220651]

# %%
other = [0.05793780833482742
,0.13974592089653015
,0.11955593526363373
,0.14261603355407715
,0.5091529488563538
,0.12647554278373718
,0.1964726597070694
,0.20617005228996277
,0.2517193853855133
,0.2374100685119629
,0.5759555697441101
,0.6607595086097717
,0.9419299960136414
,0.8365108370780945
,0.8170280456542969
,0.500332236289978
,0.40127795934677124
,0.2981471121311188
,0.20960257947444916]
X = list(range(0,16*19,16))
print(X)
mpl.rc('font', family='serif')
plt.style.use('bmh')
fig, ax = plt.subplots(figsize=(6.5, 4))
l1, = plt.plot(X, corn_sample, color='#FFD300')
l2, = plt.plot(X, other, color='#999999')
ax.legend(handles=[l1, l2], labels=['Corn', 'Unknown Crop'], loc='best', prop={'size':14})
ax.set_xlabel('Time/Day',size=16)
ax.set_ylabel('NDVI',size=16)
ax.tick_params(axis='y',labelsize=16)
ax.tick_params(axis='x',labelsize=16)
plt.savefig('1.png',dpi=330,format='png',bbox_inches='tight')
files.download('1.png')
# Out:
# [0, 16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256, 272, 288]

# %%
other = [0.0644703209400177
,0.19453924894332886
,0.17677755653858185
,0.1976301372051239
,0.22564361989498138
,0.6111850738525391
,0.7711321115493774
,0.667373538017273
,0.8214702606201172
,0.6409631371498108
,0.8901389837265015
,0.9078372120857239
,0.9496062994003296
,0.9252747297286987
,0.8192488551139832
,0.4358595311641693
,0.5679012537002563
,0.36466166377067566
,0.25832971930503845]
X = list(range(0,16*19,16))
print(X)
mpl.rc('font', family='serif')
plt.style.use('bmh')
fig, ax = plt.subplots(figsize=(6.5, 4))
l1, = plt.plot(X, corn_sample, color='#FFD300')
l2, = plt.plot(X, other, color='#999999')
ax.legend(handles=[l1, l2], labels=['Corn', 'Unknown Crop'], loc='best', prop={'size':14})
ax.set_xlabel('Time/Day',size=16)
ax.set_ylabel('NDVI',size=16)
ax.tick_params(axis='y',labelsize=16)
ax.tick_params(axis='x',labelsize=16)
plt.savefig('2.png',dpi=330,format='png',bbox_inches='tight')
files.download('2.png')
# Out:
# [0, 16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256, 272, 288]

# %%
other = [0.0800856500864029
,0.13582296669483185
,0.11357633024454117
,0.12589755654335022
,0.1820608675479889
,0.13297207653522491
,0.24004924297332764
,0.3196622431278229
,0.25245901942253113
,0.4268462657928467
,0.5823230147361755
,0.6427617073059082
,0.743523895740509
,0.7146672606468201
,0.6774193644523621
,0.41657811403274536
,0.29794999957084656
,0.1766602247953415
,0.15844155848026276]
X = list(range(0,16*19,16))
print(X)
fig, ax = plt.subplots()
l1, = plt.plot(X, corn_sample, color='green')
l2, = plt.plot(X, other, color='gray')
# ax.legend(handles=[l1, l2], labels=['corn sample', 'unknown crop'], loc='best', prop={'size':13})
ax.set_xlabel('Time/Day',size=20)
ax.set_ylabel('NDVI',size=20)
ax.tick_params(axis='y',labelsize=20)
ax.tick_params(axis='x',labelsize=20)
plt.savefig('corn-3.png',dpi=330,format='png',bbox_inches='tight')
files.download('corn-3.png')
# Out:
# [0, 16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256, 272, 288]

# %%
other = [0.07220573723316193
,0.1135135143995285
,0.0962301567196846
,0.13632090389728546
,0.26173773407936096
,0.27547168731689453
,0.7643271088600159
,0.683722734451294
,0.6242861151695251
,0.8531343340873718
,0.8871103525161743
,0.934661328792572
,0.9013079404830933
,0.8619306683540344
,0.73128741979599
,0.47145187854766846
,0.3460519313812256
,0.22115784883499146
,0.21959459781646729]
X = list(range(0,16*19,16))
print(X)
fig, ax = plt.subplots()
l1, = plt.plot(X, corn_sample, color='green')
l2, = plt.plot(X, other, color='gray')
# ax.legend(handles=[l1, l2], labels=['corn sample', 'unknown crop'], loc='best', prop={'size':13})
ax.set_xlabel('Time/Day',size=20)
ax.set_ylabel('NDVI',size=20)
ax.tick_params(axis='y',labelsize=20)
ax.tick_params(axis='x',labelsize=20)
plt.savefig('corn-4.png',dpi=330,format='png',bbox_inches='tight')
files.download('corn-4.png')
# Out:
# [0, 16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256, 272, 288]

# %%
# wheat-corn样本NDVI时间序列
wheat_corn_sample = [0.10671936720609665,0.08583036810159683,0.08926014602184296,0.10259918123483658,0.1906421035528183,0.6444080471992493,0.8714208602905273,0.7807813882827759
,0.7036849856376648,0.4080178141593933,0.24670249223709106,0.2985212504863739,0.6099628806114197,0.8201082348823547,0.6806796193122864,0.24042484164237976,0.0714285746216774
,0.06623286008834839,0.05121293663978577,0.04965156689286232]

# %%
other = [0.1302037239074707
,0.10443349927663803
,0.1241595670580864
,0.07000000029802322
,0.2837209403514862
,0.7984496355056763
,0.6905016303062439
,0.6352555155754089
,0.687933087348938
,0.4616509974002838
,0.42584747076034546
,0.419739693403244
,0.47450509667396545
,0.23372365534305573
,0.23162274062633514
,0.2159709632396698
,0.1626262664794922
,0.1440366953611374
,0.1340508759021759
,0.12559756636619568]
X = list(range(0,16*20,16))
print(X)
fig, ax = plt.subplots()
l1, = plt.plot(X, wheat_corn_sample, color='#ffd300')
l2, = plt.plot(X, other, color='gray')
# ax.legend(handles=[l1, l2], labels=['wheat-corn sample', 'unknown crop'], loc='best', prop={'size':13})
ax.set_xlabel('Time/Day',size=20)
ax.set_ylabel('NDVI',size=20)
ax.tick_params(axis='y',labelsize=20)
ax.tick_params(axis='x',labelsize=20)
plt.savefig('wheat_corn-1.png',dpi=330,format='png',bbox_inches='tight')
files.download('wheat_corn-1.png')
# Out:
# [0, 16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256, 272, 288, 304]

# %%
other = [0.07853025943040848
,0.0669565200805664
,0.05936422944068909
,0.05809979513287544
,0.06676187366247177
,0.5606375336647034
,0.610870897769928
,0.4148082137107849
,0.3848111927509308
,0.23062309622764587
,0.2191951996088028
,0.2285614311695099
,0.25192221999168396
,0.3004032373428345
,0.23870417475700378
,0.16906747221946716
,0.18388143181800842
,0.12311015278100967
,0.1369112879037857
,0.10304789245128632]
X = list(range(0,16*20,16))
print(X)
mpl.rc('font', family='serif')
plt.style.use('bmh')
fig, ax = plt.subplots(figsize=(6.5, 4))
l1, = plt.plot(X, wheat_corn_sample, color='#A57000')
l2, = plt.plot(X, other, color='#999999')
ax.legend(labels=['Wheat-Corn', 'Unknown Crop'], loc=8, prop={'size':14})
ax.set_xlabel('Time/Day',size=16)
ax.set_ylabel('NDVI',size=16)
ax.tick_params(axis='y',labelsize=16)
ax.tick_params(axis='x',labelsize=16)
plt.savefig('3.png',dpi=330,format='png',bbox_inches='tight')
files.download('3.png')
# Out:
# [0, 16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256, 272, 288, 304]

# %%
# wheat样本NDVI时间序列
wheat_sample = [0.034849680960178375,0.2939925491809845,0.20509953796863556,0.19825169444084167,0.4471520185470581,0.4679482877254486,0.7881203889846802,0.8338026404380798
,0.6034454107284546,0.3938875198364258,0.26683080196380615,0.15939652919769287,0.20690712332725525,0.15400204062461853,0.11472413688898087,0.16813971102237701,0.29661309719085693
,0.49322575330734253,0.36290812492370605,0.0013699481496587396]

# %%
other = [0.3029805123806
,0.2884792685508728
,0.208779439330101
,0.18204739689826965
,0.7003529071807861
,0.7535748481750488
,0.8464595079421997
,0.8654724955558777
,0.3790687620639801
,0.6905311942100525
,0.5756621956825256
,0.2712477445602417
,0.364827960729599
,0.20142094984650612
,0.6637681126594543
,0.06744328886270523
,0.2455851137638092
,0.25776052474975586
,0.09118086844682693
,0.010664478875696659]
X = list(range(0,16*20,16))
print(X)
mpl.rc('font', family='serif')
plt.style.use('bmh')
fig, ax = plt.subplots(figsize=(6.5, 4))
l1, = plt.plot(X, wheat_corn_sample, color='#A57000')
l2, = plt.plot(X, other, color='#999999')
ax.legend(labels=['Wheat', 'Unknown Crop'], loc=8, prop={'size':14})
ax.set_xlabel('Time/Day',size=16)
ax.set_ylabel('NDVI',size=16)
ax.tick_params(axis='y',labelsize=16)
ax.tick_params(axis='x',labelsize=16)
plt.savefig('4.png',dpi=330,format='png',bbox_inches='tight')
files.download('4.png')
# Out:
# [0, 16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256, 272, 288, 304]

# %%
other = [0.32477736473083496
,0.3115987479686737
,0.2600127160549164
,0.2754966914653778
,0.7847457528114319
,0.7340782284736633
,0.9107939600944519
,0.9142744541168213
,0.847836434841156
,0.6215881109237671
,0.512632429599762
,0.3280254900455475
,0.7146086692810059
,0.7664101123809814
,0.8369140625
,0.1256544440984726
,0.36437246203422546
,0.26775407791137695
,0.19647859036922455
,0.0709112361073494]
X = list(range(0,16*20,16))
print(X)
fig, ax = plt.subplots()
l1, = plt.plot(X, wheat_sample, color='#a57000')
l2, = plt.plot(X, other, color='gray')
# ax.legend(handles=[l1, l2], labels=['wheat sample', 'unknown crop'], loc='best', prop={'size':13})
ax.set_xlabel('Time/Day',size=20)
ax.set_ylabel('NDVI',size=20)
ax.tick_params(axis='y',labelsize=20)
ax.tick_params(axis='x',labelsize=20)
plt.savefig('wheat-2.png',dpi=330,format='png',bbox_inches='tight')
files.download('wheat-2.png')
# Out:
# [0, 16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256, 272, 288, 304]

# %%
corn_sample = [0.12158111, 0.13675252, 0.11746047, 0.15103779, 0.13258463, 0.17043263,
  0.27664024, 0.41980866, 0.66803447, 0.78002375, 0.84764778, 0.88367154,
  0.82070537, 0.68194665, 0.56755694, 0.27573394, 0.27925092, 0.25687497,
  0.220651, 0.23]
fig, ax = plt.subplots()
l1, = plt.plot(X, corn_sample, color='green')
l2, = plt.plot(X, wheat_corn_sample, color='#ffd300')
l3, = plt.plot(X, wheat_sample, color='#a57000')
l4, = plt.plot(X, other, color='gray')
ax.legend(handles=[l1, l2, l3, l4], labels=['corn sample', 'wheat_corn sample',  'wheat sample', 'unknown crop'], loc='best', prop={'size':30}, framealpha=1)

# legend =legend.get_frame().set_facecolor('C0')
plt.savefig('legend.png',dpi=330,format='png',bbox_inches='tight')
files.download('legend.png')
